# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_terrorism=pd.read_csv("SPARKS-globalterrorismdb_0718dist.csv", encoding='ISO-8859-1', low_memory=False)

# %%
df_terrorism.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df_terrorism.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   eventid             float64
#  1   iyear               int64
#  2   imonth              int64
#  3   iday                int64
#  4   approxdate          object
#  5   extended            int64
#  6   resolution          object
#  7   country             int64
#  8   country_txt         object
#  9   region              int64
#  10  region_txt          object
#  11  provstate           object
#  12  city                object
#  13  latitude            float64
#  14  longitude           float64
#  15  specificity         float64
#  16  vicinity            int64
#  17  location            object
#  18  summary             object
#  19  crit1               int64
#  20  crit2               int64
#  21  crit3               int64
#  22  doubtterr           float64
#  23  alternative         float64
#  24  alternative_txt     object
#  25  multiple            float64
#  26  success             int64
#  27  suicide             int64
#  28  attacktype1         int64
#  29  attacktype1_txt     object
#  30  attacktype2         float64
#  31  attacktype2_txt     object
#  32  attacktype3         float64
#  33  attacktype3_txt     object
#  34  targtype1           int64
#  35  targtype1_txt       object
#  36  targsubtype1        float64
#  37  targsubtype1_txt    object
#  38  corp1               object
#  39  target1             object
#  40  natlty1             float64
#  41  natlty1_txt         object
#  42  targtype2           float64
#  43  targtype2_txt       object
#  44  targsubtype2        float64
#  45  targsubtype2_txt    object
#  46  corp2               object
#  47  target2             object
#  48  natlty2             float64
#  49  natlty2_txt         object
#  50  targtype3           float64
#  51  targtype3_txt       object
#  52  targsubtype3        float64
#  53  targsubtype3_txt    object
#  54  corp3               object
#  55  target3             object
#  56  natlty3             float64
#  57  natlty3_txt         object
#  58  gname               object
#  59  gsubname            object
#  60  gname2              object
#  61  gsubname2           object
#  62  gname3              object
#  63  gsubname3           object
#  64  motive              object
#  65  guncertain1         float64
#  66  guncertain2         float64
#  67  guncertain3         float64
#  68  individual          int64
#  69  nperps              float64
#  70  nperpcap            float64
#  71  claimed             float64
#  72  claimmode           float64
#  73  claimmode_txt       object
#  74  claim2              float64
#  75  claimmode2          float64
#  76  claimmode2_txt      object
#  77  claim3              float64
#  78  claimmode3          float64
#  79  claimmode3_txt      object
#  80  compclaim           float64
#  81  weaptype1           int64
#  82  weaptype1_txt       object
#  83  weapsubtype1        float64
#  84  weapsubtype1_txt    object
#  85  weaptype2           float64
#  86  weaptype2_txt       object
#  87  weapsubtype2        float64
#  88  weapsubtype2_txt    object
#  89  weaptype3           float64
#  90  weaptype3_txt       object
#  91  weapsubtype3        float64
#  92  weapsubtype3_txt    object
#  93  weaptype4           float64
#  94  weaptype4_txt       object
#  95  weapsubtype4        float64
#  96  weapsubtype4_txt    object
#  97  weapdetail          object
#  98  nkill               float64
#  99  nkillus             float64
#  100 nkillter            float64
#  101 nwound              float64
#  102 nwoundus            float64
#  103 nwoundte            float64
#  104 property            int64
#  105 propextent          float64
#  106 propextent_txt      object
#  107 propvalue           float64
#  108 propcomment         object
#  109 ishostkid           float64
#  110 nhostkid            float64
#  111 nhostkidus          float64
#  112 nhours              float64
#  113 ndays               float64
#  114 divert              object
#  115 kidhijcountry       object
#  116 ransom              float64
#  117 ransomamt           float64
#  118 ransomamtus         float64
#  119 ransompaid          float64
#  120 ransompaidus        float64
#  121 ransomnote          object
#  122 hostkidoutcome      float64
#  123 hostkidoutcome_txt  object
#  124 nreleased           float64
#  125 addnotes            object
#  126 scite1              object
#  127 scite2              object
#  128 scite3              object
#  129 dbsource            object
#  130 INT_LOG             int64
#  131 INT_IDEO            int64
#  132 INT_MISC            int64
#  133 INT_ANY             int64
#  134 related             object
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df_terrorism.shape
# Out:
# (181691, 135)

# %%
df_terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df_terrorism.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df_terr=df_terrorism[['eventid', 'iyear','country_txt','region_txt', 'provstate', 'city', 'latitude', 'longitude', 'crit1', 'crit2',
                      'crit3','success', 'suicide', 'attacktype1_txt', 'targtype1_txt', 'targsubtype1_txt', 'natlty1_txt', 'gname', 'guncertain1', 
                      'claimed','weaptype1_txt','nkill', 'nwound','propextent_txt', 'weapsubtype1_txt']]




df_terr.rename(columns={'eventid': 'EventId', 'iyear':'Year','country_txt': 'Country','region_txt':'Region', 'provstate': 'Provstate', 
                        'city':'City', 'latitude':'Latitude', 'longitude':'Longitude', 'crit1':'Crit1', 'crit2':'Crit2','crit3':'Crit3',
                        'success':'Success', 'suicide':'Suicide', 'attacktype1_txt':'AttackType', 'targtype1_txt':'TargetType', 'targsubtype1_txt':'TargetSubType',
                        'natlty1_txt':'Nationality', 'gname':'Group', 'guncertain1':'Guncertain1','claimed':'Claimed','weaptype1_txt':'WeaponType','nkill':'Killed', 
                        'nwound':'Wounded','propextent_txt':'DamageExtent', 'weapsubtype1_txt':'WeaponDetail'}, inplace=True)
# Out:
# C:\Users\Arpita\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_terr.columns
# Out:
# Index(['EventId', 'Year', 'Country', 'Region', 'Provstate', 'City', 'Latitude',
#        'Longitude', 'Crit1', 'Crit2', 'Crit3', 'Success', 'Suicide',
#        'AttackType', 'TargetType', 'TargetSubType', 'Nationality', 'Group',
#        'Guncertain1', 'Claimed', 'WeaponType', 'Killed', 'Wounded',
#        'DamageExtent', 'WeaponDetail'],
#       dtype='object')

# %%
df_terr['Casualties']= df_terr['Killed']+df_terr['Wounded']
# Out:
# <ipython-input-14-ce9e4b6ce497>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_terr['Casualties']= df_terr['Killed']+df_terr['Wounded']

# %%
df_terr.isnull().sum()
# Out:
# EventId               0
# Year                  0
# Country               0
# Region                0
# Provstate           421
# City                434
# Latitude           4556
# Longitude          4557
# Crit1                 0
# Crit2                 0
# Crit3                 0
# Success               0
# Suicide               0
# AttackType            0
# TargetType            0
# TargetSubType     10373
# Nationality        1559
# Group                 0
# Guncertain1         380
# Claimed           66120
# WeaponType            0
# Killed            10313
# Wounded           16311
# DamageExtent     117626
# WeaponDetail      20768
# Casualties        16874
# dtype: int64

# %%
df_terr['Country'].value_counts().head()
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: Country, dtype: int64

# %%
df_terr['Region'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
df_terr['City'].value_counts().head()
# Out:
# Unknown    9775
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Name: City, dtype: int64

# %%
df_terr['Group'].value_counts().head()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Name: Group, dtype: int64

# %%
df_terr['AttackType'].value_counts().head()
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: AttackType, dtype: int64

# %%
df_terr['TargetType'].value_counts().head()
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: TargetType, dtype: int64

# %%
df_terr['TargetSubType'].value_counts().head()
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Name: TargetSubType, dtype: int64

# %%
print('Country with the Highest Number of Terrorist Attacks:',df_terr['Country'].value_counts().index[0])
print('Region with the Highest Number of Terrorist Attacks:',df_terr['Region'].value_counts().index[0])
# Out:
# Country with the Highest Number of Terrorist Attacks: Iraq
# Region with the Highest Number of Terrorist Attacks: Middle East & North Africa

# %% [markdown]
# ### Highest Number of People Killed in an Attack

# %%
print('Maximum people killed in an attack are:',df_terr['Killed'].max(),'that took place in',df_terr.loc[df_terr['Killed'].idxmax()].Country)
# Out:
# Maximum people killed in an attack are: 1570.0 that took place in Iraq

# %% [markdown]
# ### Yearwise Number Of Terrorist Attacks

# %%
df_terr['Year'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %% [markdown]
# ###  Nationality of Target Groups

# %%
pd.DataFrame(df_terr['Nationality'].value_counts())
# Out:
#                                 Nationality
# Iraq                                  24113
# Pakistan                              13900
# India                                 12098
# Afghanistan                           10931
# Colombia                               7922
# ...                                     ...
# Marshall Islands                          1
# Man, Isle of                              1
# Antigua and Barbuda                       1
# People's Republic of the Congo            1
# Greenland                                 1
#
# [215 rows x 1 columns]

# %% [markdown]
# ### Nationality of the Maximally targeted group

# %%
print("Nationality of the maximally targetted group is:", df_terr['Nationality'].value_counts().index[0])
# Out:
# Nationality of the maximally targetted group is: Iraq

# %% [markdown]
# ### Weapons Mostly used to carry out Attacks

# %%
print('Maximum Number of Attacks were carried out using:', df_terr['WeaponType'].value_counts().index[0])
# Out:
# Maximum Number of Attacks were carried out using: Explosives

# %% [markdown]
# ### Countries that saw Major Damage

# %%
pd.DataFrame(df_terr[df_terr['DamageExtent'] == 'Major (likely >= $1 million but < $1 billion)']['Country'])
# Out:
#               Country
# 14      United States
# 54      United States
# 80        Switzerland
# 129     United States
# 209     United States
# ...               ...
# 170568          India
# 172897          Chile
# 178399          Chile
# 178612       Colombia
# 179738          Egypt
#
# [909 rows x 1 columns]

# %% [markdown]
# ### Maximum used Explosives

# %%
pd.DataFrame({'Number of Times a Weapon is Used': df_terr[df_terr['WeaponType']=='Explosives']['WeaponDetail'].value_counts().drop('Unknown Explosive Type')})
# Out:
#                                            Number of Times a Weapon is Used
# Vehicle                                                                9899
# Projectile (rockets, mortars, RPGs, etc.)                              9848
# Other Explosive Type                                                   7304
# Grenade                                                                5167
# Landmine                                                               4251
# Suicide (carried bodily by human being)                                3245
# Remote Trigger                                                         2719
# Sticky Bomb                                                            1594
# Dynamite/TNT                                                           1222
# Time Fuse                                                               792
# Pipe Bomb                                                               625
# Letter Bomb                                                             548
# Pressure Trigger                                                        219
# Unknown Gun Type                                                          1

# %% [markdown]
# ### Data Visualization

# %%
yearwise_count=pd.DataFrame({'No. of Incidents':df_terr.groupby(['Year'])['Year'].count(),
                                                        'No. of Casualities': df_terr.groupby(['Year'])['Casualties'].sum()})
yearwise_count
# Out:
#       No. of Incidents  No. of Casualities
# Year
# 1970               651               367.0
# 1971               471               119.0
# 1972               568               602.0
# 1973               473               621.0
# 1974               581              1122.0
# 1975               740               781.0
# 1976               923              1158.0
# 1977              1319               874.0
# 1978              1526              2664.0
# 1979              2662              4378.0
# 1980              2662              7532.0
# 1981              2586              8106.0
# 1982              2544              7512.0
# 1983              2870             11271.0
# 1984              3495             15462.0
# 1985              2915             12004.0
# 1986              2860             10524.0
# 1987              3183             12141.0
# 1988              3721             14014.0
# 1989              4324             13617.0
# 1990              3887             13261.0
# 1991              4683             15961.0
# 1992              5071             19610.0
# 1994              3456             14663.0
# 1995              3081             20233.0
# 1996              3058             17383.0
# 1997              3197             19468.0
# 1998               934             10754.0
# 1999              1395              7819.0
# 2000              1814              8890.0
# 2001              1906             29662.0
# 2002              1333             10356.0
# 2003              1278             10126.0
# 2004              1166             16911.0
# 2005              2017             18258.0
# 2006              2758             23740.0
# 2007              3242             33728.0
# 2008              4805             27594.0
# 2009              4721             27210.0
# 2010              4826             23651.0
# 2011              5076             22566.0
# 2012              8522             39381.0
# 2013             12036             57679.0
# 2014             16903             68853.0
# 2015             14965             72833.0
# 2016             13587             69225.0
# 2017             10900             48208.0

# %% [markdown]
# ### Number of Terrorist Attacks Each Year

# %%
plt.subplots(figsize = (15, 6))
plt.bar(df_terr['Year'].value_counts().index, df_terr['Year'].value_counts())
plt.xticks(rotation = 90)
plt.xlabel("Year of Attack")
plt.ylabel("Count")
plt.title("Number of Terrorist Activities Each Year")
plt.show()

# %%
plt.subplots(figsize = (15, 6))
plt.bar(df_terr['Year'].value_counts().index, df_terr.groupby(['Year'])['Casualties'].sum())
plt.xticks(rotation = 90)
plt.xlabel("Year of Attack")
plt.ylabel("Casualities")
plt.title("Yearwise Casualities")
plt.show()

# %% [markdown]
# ### Attacking Methods used by Terrorists

# %%
plt.subplots(figsize = (15, 4))
plt.bar(df_terr['AttackType'].value_counts().index, df_terr['AttackType'].value_counts())
plt.xticks(rotation = 90)
plt.xlabel('Attack Type')
plt.title('Attacking Methods by Terrorists')
plt.show()

# %%
data1=pd.DataFrame({'Casualties':df_terr.groupby(['AttackType'])['Casualties'].sum(),
              'Incidents': df_terr.groupby(['AttackType'])['Country'].count(),
              'Casuality Rate': df_terr.groupby(['AttackType'])['Casualties'].sum()/df_terr.groupby(['AttackType'])['Country'].count()})

data1.reset_index(inplace=True)
data1
# Out:
#                             AttackType  Casualties  Incidents  Casuality Rate
# 0                        Armed Assault    212386.0      42669        4.977525
# 1                        Assassination     37209.0      19312        1.926729
# 2                    Bombing/Explosion    514233.0      88255        5.826673
# 3       Facility/Infrastructure Attack      6293.0      10356        0.607667
# 4                            Hijacking     20642.0        659       31.323217
# 5  Hostage Taking (Barricade Incident)      7465.0        991        7.532795
# 6          Hostage Taking (Kidnapping)     20267.0      11158        1.816365
# 7                      Unarmed Assault     14791.0       1015       14.572414
# 8                              Unknown     39606.0       7276        5.443375

# %%
data2=pd.DataFrame({'Casualties':df_terr.groupby(['Year'])['Casualties'].sum(),
              'Incidents': df_terr.groupby(['Year'])['Country'].count(),
              'Casuality Rate': df_terr.groupby(['Year'])['Casualties'].sum()/df_terr.groupby(['Year'])['Country'].count()})

data2.reset_index(inplace=True)
data2
# Out:
#     Year  Casualties  Incidents  Casuality Rate
# 0   1970       367.0        651        0.563748
# 1   1971       119.0        471        0.252654
# 2   1972       602.0        568        1.059859
# 3   1973       621.0        473        1.312896
# 4   1974      1122.0        581        1.931153
# 5   1975       781.0        740        1.055405
# 6   1976      1158.0        923        1.254605
# 7   1977       874.0       1319        0.662623
# 8   1978      2664.0       1526        1.745740
# 9   1979      4378.0       2662        1.644628
# 10  1980      7532.0       2662        2.829452
# 11  1981      8106.0       2586        3.134571
# 12  1982      7512.0       2544        2.952830
# 13  1983     11271.0       2870        3.927178
# 14  1984     15462.0       3495        4.424034
# 15  1985     12004.0       2915        4.118010
# 16  1986     10524.0       2860        3.679720
# 17  1987     12141.0       3183        3.814326
# 18  1988     14014.0       3721        3.766192
# 19  1989     13617.0       4324        3.149167
# 20  1990     13261.0       3887        3.411629
# 21  1991     15961.0       4683        3.408285
# 22  1992     19610.0       5071        3.867087
# 23  1994     14663.0       3456        4.242766
# 24  1995     20233.0       3081        6.567024
# 25  1996     17383.0       3058        5.684434
# 26  1997     19468.0       3197        6.089459
# 27  1998     10754.0        934       11.513919
# 28  1999      7819.0       1395        5.605018
# 29  2000      8890.0       1814        4.900772
# 30  2001     29662.0       1906       15.562434
# 31  2002     10356.0       1333        7.768942
# 32  2003     10126.0       1278        7.923318
# 33  2004     16911.0       1166       14.503431
# 34  2005     18258.0       2017        9.052058
# 35  2006     23740.0       2758        8.607687
# 36  2007     33728.0       3242       10.403455
# 37  2008     27594.0       4805        5.742768
# 38  2009     27210.0       4721        5.763609
# 39  2010     23651.0       4826        4.900746
# 40  2011     22566.0       5076        4.445626
# 41  2012     39381.0       8522        4.621098
# 42  2013     57679.0      12036        4.792207
# 43  2014     68853.0      16903        4.073419
# 44  2015     72833.0      14965        4.866889
# 45  2016     69225.0      13587        5.094944
# 46  2017     48208.0      10900        4.422752

# %%
plt.subplots(figsize = (15, 6))
plt.plot(data2['Year'],  data2['Casuality Rate'], linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='green', markersize=10)
plt.xticks(rotation = 90)
plt.xlabel("Year of Attack")
plt.ylabel("Casuality Rate")
plt.show()

# %% [markdown]
# ### Top 20 Countries Witnessing Maximum Terror Attacks

# %%
df_terr['Country'].value_counts().head(20)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
plt.subplots(figsize = (15, 4))
plt.bar(df_terr['Country'].value_counts().head(20).index, df_terr['Country'].value_counts().head(20))
plt.xticks(rotation = 90)
plt.xlabel('Most Attacked Countries')
plt.title('Frequency of Attacks in Top 20 Most Attacked Countries')
plt.show()

# %% [markdown]
# ### Terrorism Groups

# %%
df_terr['Group'].value_counts().head(20).drop('Unknown')
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# Palestinians                                        1125
# Houthi extremists (Ansar Allah)                     1062
# Al-Qaida in the Arabian Peninsula (AQAP)            1020
# Name: Group, dtype: int64

# %%
plt.subplots(figsize = (15, 4))
plt.bar(df_terr['Group'].value_counts().head(20).drop('Unknown').index, df_terr['Group'].value_counts().head(20).drop('Unknown'))
plt.xticks(rotation = 90)
plt.xlabel('Terrorism Groups')
plt.ylabel('No. of Attacks')
plt.title('Frequency of Attacks by a Terror Group')
plt.show()

# %%
df_terr['Nationality'].value_counts().head(20)
# Out:
# Iraq                24113
# Pakistan            13900
# India               12098
# Afghanistan         10931
# Colombia             7922
# Philippines          6685
# Peru                 5840
# El Salvador          5212
# United States        5065
# Turkey               4636
# Israel               4097
# Thailand             3804
# Nigeria              3759
# Northern Ireland     3367
# Somalia              3160
# Yemen                3123
# Spain                3096
# France               2918
# Sri Lanka            2851
# International        2699
# Name: Nationality, dtype: int64

# %% [markdown]
# ### Mostly Targeted Places

# %%
df_terr['TargetType'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: TargetType, dtype: int64

# %%
plt.subplots(figsize = (15, 8))
plt.bar(df_terr['TargetType'].value_counts().index, df_terr['TargetType'].value_counts())
plt.xticks(rotation = 90)
plt.xlabel('Targeted Places')
plt.ylabel('No. of Attacks')
plt.title('Frequency of Attacks in Targeted Places')
plt.show()
